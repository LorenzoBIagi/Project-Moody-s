# %%
import numpy as np

# %%
import xfacpy
import tenpy

# Stampa di conferma con i percorsi dei moduli
print("xfacpy path:", getattr(xfacpy, "__file__", None))
print("tenpy path:", getattr(tenpy, "__file__", None))

print("Entrambi i pacchetti sono importati correttamente.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import xfacpy
#       2 import tenpy
#       4 # Stampa di conferma con i percorsi dei moduli
#
# ModuleNotFoundError: No module named 'xfacpy'
