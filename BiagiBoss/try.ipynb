# %%
import sys
import numpy as np
import math
sys.path.append("../build/python")  # set to correct path for module
import xfacpy

def fun1(xs):
        x,y,c=0,0,0
        for xi in xs:
            c=c+1
            x=x+c*xi
            y=y+xi*xi/c
        
        arg=1.0+(x+2*y+x*y)*math.pi;
        return 1+x+np.cos(arg) + 1j * x*x+0.5*np.sin(arg)
def myTf(xs):
    myTf.c += 1
    return fun1(xs)
myTf.c = 0
dim=5
[xi,wi]=xfacpy.GK15(0,1)
ci=xfacpy.CTensorCI1_complex(myTf, [xi]*dim);
print("rank neval pivotError integral(f)")
for i in range(1, 121):
    ci.iterate()
    if i % 10 == 0:
        print(i, myTf.c, ci.pivotError[-1], ci.get_TensorTrain().sum([wi]*dim))
print("mps: ", [M.shape for M in ci.get_TensorTrain().core])
# Out:
# rank neval pivotError integral(f)
# 10 7059 4.033998186110615 (8.677917150896924+60.817608942758085j)
# 20 23182 4.6606528686917 (8.488831971439447+60.832931291185425j)
# 30 44427 2.2293667849235566 (8.50008891318714+60.832986864432826j)
# 40 67635 0.5941337055476643 (8.510316186309751+60.83325634306179j)
# 50 89653 0.3322388238203579 (8.500862845778896+60.83332892555476j)
# 60 114817 0.08698266821507379 (8.50054774363351+60.83333274306884j)
# 70 146983 0.020113234310647186 (8.500087174002267+60.83333321464554j)
# 80 179080 0.005019677504385187 (8.499990226624824+60.833333332344296j)
# 90 217215 0.0015941140860565562 (8.500000161674743+60.83333333349783j)
# 100 253745 0.00032409913401224895 (8.5000100290246+60.833333333326486j)
# 110 290567 0.00020249662402269778 (8.50001118075188+60.83333333333531j)
# 120 334750 8.400336934322536e-05 (8.500011212692776+60.83333333333328j)
# mps:  [(1, 15, 15), (15, 15, 120), (120, 15, 120), (120, 15, 15), (15, 15, 1)]
