# %%
import sys
import numpy as np
import math
sys.path.append("../build/python")  # set to correct path for module
import xfacpy

def fun1(xs):
        x,y,c=0,0,0
        for xi in xs:
            c=c+1
            x=x+c*xi
            y=y+xi*xi/c
        
        arg=1.0+(x+2*y+x*y)*math.pi;
        return 1+x+np.cos(arg) + 1j * x*x+0.5*np.sin(arg)
def myTf(xs):
    myTf.c += 1
    return fun1(xs)
myTf.c = 0
dim=5
[xi,wi]=xfacpy.GK15(0,1)
ci=xfacpy.CTensorCI1_complex(myTf, [xi]*dim);
print("rank neval pivotError integral(f)")
for i in range(1, 121):
    ci.iterate()
    if i % 10 == 0:
        print(i, myTf.c, ci.pivotError[-1], ci.get_TensorTrain().sum([wi]*dim))
print("mps: ", [M.shape for M in ci.get_TensorTrain().core])
# Out:
# rank neval pivotError integral(f)
# 10 6196 3.91339933173582 (8.376227481892144+60.6657677657661j)
# 20 21548 4.705961056703657 (8.518439588744855+60.831201492132365j)
# 30 42585 2.043236200336503 (8.511483991760482+60.8335085782702j)
# 40 62681 0.880097027114768 (8.497799568302938+60.83333617961111j)
# 50 87592 0.20288504813273034 (8.500397893918407+60.833332963121784j)
# 60 116345 0.08937810029688213 (8.500347674370243+60.833333853874834j)
# 70 146510 0.03208969738528511 (8.499970506706726+60.83333333214959j)
# 80 181285 0.0028334317682250088 (8.499990911688293+60.8333333319375j)
# 90 215009 0.0021271326923745244 (8.500011035208264+60.83333333362578j)
# 100 250086 0.0003771762783607833 (8.500011231413174+60.833333333337556j)
# 110 296477 0.0001266492088703479 (8.50001111370816+60.833333333332796j)
# 120 338643 4.6655133280483383e-05 (8.500011177557125+60.833333333333286j)
# mps:  [(1, 15, 15), (15, 15, 120), (120, 15, 120), (120, 15, 15), (15, 15, 1)]
